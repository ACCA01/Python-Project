# %%
a = 6
b = 2
c = a/b
print(c)
# Out:
# 3.0

# %%
a = 6
b = 0
c = a/b
print(c)
print("Complete")

# %%
# ZeroDivisionError is an exception

# %% [markdown]
# # use try: ... except: ... to handle exception

# %%
a = 6
b = 0
try:
    c = a/b
    print(c)
except:
    print("Error")
# Out:
# Error

# %%
a = 6
b = 0
try:
    c = a/b
    print(c)
except Exception as e: # This line captures any variants of exceptions
    print(e)
# Out:
# division by zero

# %%
a = 6
b = 0
try:
    c = a/b
    print(c)
except ZeroDivisionError as e: # preferred way
    print(e)
# Out:
# division by zero

# %%
a = 6
b = 0
if b == 0:
    raise ValueError("b cannot be zero")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a0b0847d6a14> in <cell line: 3>()
#       2 b = 0
#       3 if b == 0:
# ----> 4     raise ValueError("b cannot be zero")
#
# ValueError: b cannot be zero

# %% [markdown]
# # Raising your custom exception

# %%
class MyError(Exception):
    pass

# %%
a = 6
b = 0
if b == 0:
    raise MyError("b chai zero vayo hai")
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# <ipython-input-18-93241ceaa65f> in <cell line: 3>()
#       2 b = 0
#       3 if b == 0:
# ----> 4     raise MyError("b chai zero vayo hai")
#
# MyError: b chai zero vayo hai
